# %% [markdown]
# <a href="https://colab.research.google.com/github/sujataprasad01/SQL-Query-IMDB-Dataset-Analysis/blob/main/Project1_SQL_Query_IMDB_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries

# %%
#Numerical python
import numpy as np
#Data manipulation tool
import pandas as pd
#Data visualization tool
import matplotlib.pyplot as plt
#Data visualization tool
import seaborn as sns
#Server-less database
import sqlite3

# %% [markdown]
# # Establishing the connection to the databse

# %%
#Created database
db="/content/drive/MyDrive/Colab Notebooks/movie.sqlite"
#Establishing the connection with the database
conn=sqlite3.connect(db)
#Created cursor object
cur=conn.cursor()

# %% [markdown]
# # Question 1: Can you get all data about movies?

# %%
#use the cursor object to call the execute() method to execute any SQL queries.
cur.execute('SELECT * FROM movies')

# %%
#fetchall() --> fetch all rows for the current query
movies=cur.fetchall()

# %%
#Displaying the database data
movies
# Out:
# [(43597,
#   'Avatar',
#   237000000,
#   150,
#   '2009-12-10',
#   2787965087,
#   'Avatar',
#   7.2,
#   11800,
#   'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'Enter the World of Pandora.',
#   19995,
#   4762),
#  (43598,
#   "Pirates of the Caribbean: At World's End",
#   300000000,
#   139,
#   '2007-05-19',
#   961000000,
#   "Pirates of the Caribbean: At World's End",
#   6.9,
#   4500,
#   'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.',
#   'At the end of the world, the adventure begins.',
#   285,
#   4763),
#  (43599,
#   'Spectre',
#   245000000,
#   107,
#   '2015-10-26',
#   880674609,
#   'Spectre',
#   6.3,
#   4466,
# ...

# %%
#Creating dataframe
df1=pd.DataFrame(movies, columns=['id', 'original name', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average','vote_count', 'overview', 'tagline', 'uid', 'director_id' ])

# %%
df1
# Out:
#          id                             original name     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
# ...

# %%
df1.shape
# Out:
# (4773, 13)

# %%
df1.head()
# Out:
#       id                             original name     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
#
#   release_date     revenue                                     title  \
# 0   2009-12-10  2787965087                                    Avatar
# 1   2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2   2015-10-26   880674609                                   Spectre
# 3   2012-07-16  1084939099                     The Dark Knight Rises
# 4   2012-03-07   284139100                               John Carter
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             4773 non-null   int64
#  1   original name  4773 non-null   object
#  2   budget         4773 non-null   int64
#  3   popularity     4773 non-null   int64
#  4   release_date   4773 non-null   object
#  5   revenue        4773 non-null   int64
#  6   title          4773 non-null   object
#  7   vote_average   4773 non-null   float64
#  8   vote_count     4773 non-null   int64
#  9   overview       4770 non-null   object
#  10  tagline        3951 non-null   object
#  11  uid            4773 non-null   int64
#  12  director_id    4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# # Question 2: How do you get all data about directors?

# %%
cur.execute('SELECT * FROM directors')

# %%
directors=cur.fetchall()

# %%
directors
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing'),
#  ('Gore Verbinski', 4763, 2, 1704, 'Directing'),
#  ('Sam Mendes', 4764, 2, 39, 'Directing'),
#  ('Christopher Nolan', 4765, 2, 525, 'Directing'),
#  ('Andrew Stanton', 4766, 2, 7, 'Directing'),
#  ('Sam Raimi', 4767, 2, 7623, 'Directing'),
#  ('Byron Howard', 4768, 2, 76595, 'Directing'),
#  ('Joss Whedon', 4769, 2, 12891, 'Directing'),
#  ('David Yates', 4770, 2, 11343, 'Directing'),
#  ('Zack Snyder', 4771, 2, 15217, 'Directing'),
#  ('Bryan Singer', 4772, 2, 9032, 'Directing'),
#  ('Marc Forster', 4773, 2, 12995, 'Directing'),
#  ('Andrew Adamson', 4774, 2, 5524, 'Directing'),
#  ('Rob Marshall', 4775, 2, 17633, 'Directing'),
#  ('Barry Sonnenfeld', 4776, 2, 5174, 'Directing'),
#  ('Peter Jackson', 4777, 2, 108, 'Directing'),
#  ('Marc Webb', 4778, 2, 87742, 'Directing'),
#  ('Ridley Scott', 4779, 2, 578, 'Directing'),
#  ('Chris Weitz', 4780, 0, 3288, 'Directing'),
#  ('Anthony Russo', 4781, 2, 19271, 'Directing'),
# ...

# %%
df2=pd.DataFrame(directors, columns=['name', 'id', 'gender', 'uid', 'department'])

# %%
df2
# Out:
#                    name    id  gender      uid department
# 0         James Cameron  4762       2     2710  Directing
# 1        Gore Verbinski  4763       2     1704  Directing
# 2            Sam Mendes  4764       2       39  Directing
# 3     Christopher Nolan  4765       2      525  Directing
# 4        Andrew Stanton  4766       2        7  Directing
# ...                 ...   ...     ...      ...        ...
# 2344      Shane Carruth  7106       2    76624  Directing
# 2345   Neill Dela Llana  7107       0  1174437  Directing
# 2346        Scott Smith  7108       0  1219158  Directing
# 2347        Daniel Hsia  7109       2   208138  Directing
# 2348   Brian Herzlinger  7110       2    85563  Directing
#
# [2349 rows x 5 columns]

# %%
df2.shape
# Out:
# (2349, 5)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# # Question 3: Check how many movies are present in iMDB

# %%
cur.execute('SELECT title FROM movies')

# %%
count_no_mov=cur.fetchall()

# %%
count_no_mov
# Out:
# [('Avatar',),
#  ("Pirates of the Caribbean: At World's End",),
#  ('Spectre',),
#  ('The Dark Knight Rises',),
#  ('John Carter',),
#  ('Spider-Man 3',),
#  ('Tangled',),
#  ('Avengers: Age of Ultron',),
#  ('Harry Potter and the Half-Blood Prince',),
#  ('Batman v Superman: Dawn of Justice',),
#  ('Superman Returns',),
#  ('Quantum of Solace',),
#  ("Pirates of the Caribbean: Dead Man's Chest",),
#  ('The Lone Ranger',),
#  ('Man of Steel',),
#  ('The Chronicles of Narnia: Prince Caspian',),
#  ('The Avengers',),
#  ('Pirates of the Caribbean: On Stranger Tides',),
#  ('Men in Black 3',),
#  ('The Hobbit: The Battle of the Five Armies',),
#  ('The Amazing Spider-Man',),
#  ('Robin Hood',),
#  ('The Hobbit: The Desolation of Smaug',),
#  ('The Golden Compass',),
#  ('King Kong',),
#  ('Titanic',),
#  ('Captain America: Civil War',),
#  ('Battleship',),
#  ('Jurassic World',),
#  ('Skyfall',),
#  ('Spider-Man 2',),
#  ('Iron Man 3',),
#  ('Alice in Wonderland',),
# ...

# %%
#COUNT

cur.execute('SELECT COUNT(title) FROM movies')

# %%
count=cur.fetchall()

# %%
count
# Out:
# [(4773,)]

# %%
print(f"The number of movies prent in the IMDB database is {count[0]}")
# Out:
# The number of movies prent in the IMDB database is (4773,)

# %% [markdown]
# # Question 4: Find these 3 directors: James Cameron ; Luc Besson ; John Woo

# %%
# For single name

# %%
cur.execute('SELECT * FROM directors where name like "James Cameron"')

# %%
direct1=cur.fetchall()

# %%
direct1
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing')]

# %%
# For multiple names

# %%
cur.execute('SELECT * FROM directors where name in ("James Cameron", "Luc Besson", "John Woo")')

# %%
direct3=cur.fetchall()

# %%
direct3
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing'),
#  ('John Woo', 4893, 2, 11401, 'Directing'),
#  ('Luc Besson', 4949, 2, 59, 'Directing')]

# %%
# OR

# %%
cur.execute("SELECT * from directors where name == 'James Cameron' or name =='Luc Besson' or name =='John Woo'")

# %%
three_directors = cur.fetchall()

# %%
three_directors
# print(f"These 3 directors are: {three_directors}")"
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing'),
#  ('John Woo', 4893, 2, 11401, 'Directing'),
#  ('Luc Besson', 4949, 2, 59, 'Directing')]

# %% [markdown]
# # Question 5: Find all directors with name starting with Steven.

# %%
cur.execute('SELECT * FROM directors where name like "Steven%"')

# The d% pattern that uses the percent sign wildcard ( %) matches
# any string that starts with s e.g.,danger and dance,door.

# %%
steven_directors = cur.fetchall()

# %%
steven_directors
# Out:
# [('Steven Spielberg', 4799, 2, 488, 'Directing'),
#  ('Steven Soderbergh', 4909, 2, 1884, 'Directing'),
#  ('Steven Brill', 5013, 2, 32593, 'Directing'),
#  ('Steven Zaillian', 5117, 2, 2260, 'Directing'),
#  ('Steven Quale', 5216, 2, 93214, 'Directing'),
#  ('Steven Seagal', 5221, 2, 23880, 'Directing'),
#  ('Steven E. de Souza', 5390, 2, 1726, 'Directing'),
#  ('Steven Shainberg', 5803, 2, 67795, 'Directing'),
#  ('Steven R. Monroe', 6713, 2, 88039, 'Directing')]

# %% [markdown]
# # Question 6: Count female directors

# %%
cur.execute('SELECT COUNT(name) FROM directors where gender is 1')

# %%
female=cur.fetchall()

# %%
female
# Out:
# [(150,)]

# %%
cur.execute(" SELECT COUNT(*) from directors where gender == 1")

# %%
female_directors = cur.fetchall()

# %%
print(f"The numbe rof femail directors  are: {female_directors[0]}")
# Out:
# The numbe rof femail directors  are: (150,)

# %% [markdown]
# # Question 7: Find the names of the 10th first women directors? && Find the name of the 10th first women directors?

# %%
cur.execute(" SELECT name from directors where gender == 1")

# %%
female_directors_name = cur.fetchall()

# %%
female_directors_name
# Out:
# [('Brenda Chapman',),
#  ('Lilly Wachowski',),
#  ('Jennifer Yuh Nelson',),
#  ('Kathryn Bigelow',),
#  ('Nancy Meyers',),
#  ('Jill Culton',),
#  ('Mimi Leder',),
#  ('Vicky Jenson',),
#  ('Betty Thomas',),
#  ('Angelina Jolie',),
#  ('Karyn Kusama',),
#  ('Phyllida Lloyd',),
#  ('Angela Robinson',),
#  ('Beeban Kidron',),
#  ('Deepa Mehta',),
#  ('Penny Marshall',),
#  ('Julie Taymor',),
#  ('Susan Stroman',),
#  ('Catherine Hardwicke',),
#  ('Julie Anne Robinson',),
#  ('Anne Fletcher',),
#  ('Sam Taylor-Johnson',),
#  ('Joan Chen',),
#  ('Diane Keaton',),
#  ('Sofia Coppola',),
#  ('Elaine May',),
#  ('Dennie Gordon',),
#  ('Jennifer Flackett',),
#  ('Nanette Burstein',),
#  ('Liz Friedlander',),
#  ('Martha Coolidge',),
#  ('Niki Caro',),
#  ('Liliana Cavani',),
#  ('Elizabeth Banks',),
#  ('Callie Khouri',),
#  ('Sanaa Hamri',),
#  ('Jodie Foster',),
#  ('Sharon Maguire',),
#  ('Cathy Malkasian',),
#  ('Kirsten Sheridan',),
#  ('Rachel Talalay',),
#  ('Inna Evlannikova',),
# ...

# %%
female_directors_name[10]
# Out:
# ('Karyn Kusama',)

# %%
# OR

# %%
df3=pd.DataFrame(female_directors_name )

# %%
df3
# Out:
#                        0
# 0         Brenda Chapman
# 1        Lilly Wachowski
# 2    Jennifer Yuh Nelson
# 3        Kathryn Bigelow
# 4           Nancy Meyers
# ..                   ...
# 145       Marianna Palka
# 146          Ricki Stern
# 147         Lynn Shelton
# 148          Julie Davis
# 149          Lena Dunham
#
# [150 rows x 1 columns]

# %%
df3.head(10)
# Out:
#                      0
# 0       Brenda Chapman
# 1      Lilly Wachowski
# 2  Jennifer Yuh Nelson
# 3      Kathryn Bigelow
# 4         Nancy Meyers
# 5          Jill Culton
# 6           Mimi Leder
# 7         Vicky Jenson
# 8         Betty Thomas
# 9       Angelina Jolie

# %%
female_directors_name[9]
# Out:
# ('Angelina Jolie',)

# %% [markdown]
# # Question 9: What are the 3 most popular movies?

# %%
cur.execute('SELECT popularity FROM movies')

# %%
popularity=cur.fetchall()

# %%
popularity
# Out:
# [(150,),
#  (139,),
#  (107,),
#  (112,),
#  (43,),
#  (115,),
#  (48,),
#  (134,),
#  (98,),
#  (155,),
#  (57,),
#  (107,),
#  (145,),
#  (49,),
#  (99,),
#  (53,),
#  (144,),
#  (135,),
#  (52,),
#  (120,),
#  (89,),
#  (37,),
#  (94,),
#  (42,),
#  (61,),
#  (100,),
#  (198,),
#  (64,),
#  (418,),
#  (93,),
#  (35,),
#  (77,),
#  (78,),
#  (3,),
#  (89,),
#  (21,),
#  (116,),
#  (46,),
#  (89,),
#  (73,),
#  (49,),
#  (51,),
#  (59,),
#  (71,),
#  (102,),
#  (81,),
#  (118,),
#  (78,),
#  (43,),
#  (61,),
#  (62,),
#  (56,),
#  (28,),
#  (75,),
#  (51,),
#  (125,),
#  (65,),
#  (66,),
#  (22,),
#  (45,),
#  (39,),
#  (85,),
#  (42,),
#  (67,),
#  (139,),
#  (187,),
#  (92,),
#  (36,),
#  (120,),
#  (32,),
#  (40,),
#  (60,),
#  (90,),
#  (27,),
#  (79,),
#  (44,),
#  (32,),
#  (128,),
#  (94,),
#  (77,),
#  (77,),
#  (110,),
#  (243,),
#  (2,),
#  (41,),
#  (72,),
#  (44,),
#  (130,),
#  (203,),
#  (62,),
#  (47,),
#  (48,),
#  (67,),
#  (69,),
#  (481,),
#  (724,),
#  (167,),
# ...

# %%
cur.execute('SELECT original_title FROM movies ORDER BY popularity desc limit 3')

# %%
most_popoular=cur.fetchall()

# %%
most_popoular
# Out:
# [('Minions',), ('Interstellar',), ('Deadpool',)]

# %%
print(f'The 3 most popular movies are : {most_popoular[0][0]},{most_popoular[1][0]},and {most_popoular[2][0]}')
# Out:
# The 3 most popular movies are : Minions,Interstellar,and Deadpool

# %% [markdown]
# # Question 9: What are the 3 most bankable movies?

# %%
cur.execute('SELECT original_title FROM movies ORDER BY budget desc limit 3')

# %%
most_bankable=cur.fetchall()

# %%
most_bankable
# Out:
# [('Pirates of the Caribbean: On Stranger Tides',),
#  ("Pirates of the Caribbean: At World's End",),
#  ('Avengers: Age of Ultron',)]

# %% [markdown]
# # Question 10: What is the most awarded average vote since the January 1st, 2000?

# %%
cur.execute('SELECT original_title FROM movies WHERE release_date>"2000-01-01" ORDER BY vote_average desc limit 1 ')

# %%
most_awarded_avg_vote=cur.fetchall()

# %%
most_awarded_avg_vote
# Out:
# [('Sardaarji',)]

# %% [markdown]
# # Question 11: Which movie(s) were directed by Brenda Chapman?

# %%
cur.execute('SELECT movies.original_title FROM movies JOIN directors ON directors.id=movies.director_id WHERE directors.name="Brenda Chapman"')

# %%
movie_directed_by_brenda=cur.fetchall()

# %%
movie_directed_by_brenda
# Out:
# [('Brave',)]

# %% [markdown]
# # Question 12: Whose director made the most movies?

# %%
cur.execute('SELECT directors.name FROM directors JOIN movies ON movies.director_id=directors.id GROUP BY movies.director_id ORDER BY COUNT(directors.name) DESC limit 1')

# %%
mostmovie_director=cur.fetchall()

# %%
mostmovie_director
# Out:
# [('Steven Spielberg',)]

# %%
mostmovie_director[0][0]
# Out:
# 'Steven Spielberg'

# %% [markdown]
# # Question 13: Whose director is the most bankable?

# %%
cur.execute('SELECT directors.name FROM directors JOIN movies ON movies.director_id=directors.id GROUP BY movies.director_id ORDER BY sum(movies.budget) DESC limit 1')

# %%
mostbankable_director=cur.fetchall()

# %%
mostbankable_director
# Out:
# [('Steven Spielberg',)]

# %% [markdown]
# # Budget Analysis

# %% [markdown]
# # Question - List out Top 10 highest budget made movies

# %%
cur.execute('SELECT original_title, name, release_date, budget, revenue FROM movies JOIN directors ON movies.director_id=directors.id ORDER BY budget DESC limit 10')

# %%
highest_budget_movie=cur.fetchall()

# %%
highest_budget_movie
# Out:
# [('Pirates of the Caribbean: On Stranger Tides',
#   'Rob Marshall',
#   '2011-05-14',
#   380000000,
#   1045713802),
#  ("Pirates of the Caribbean: At World's End",
#   'Gore Verbinski',
#   '2007-05-19',
#   300000000,
#   961000000),
#  ('Avengers: Age of Ultron',
#   'Joss Whedon',
#   '2015-04-22',
#   280000000,
#   1405403694),
#  ('Superman Returns', 'Bryan Singer', '2006-06-28', 270000000, 391081192),
#  ('John Carter', 'Andrew Stanton', '2012-03-07', 260000000, 284139100),
#  ('Tangled', 'Byron Howard', '2010-11-24', 260000000, 591794936),
#  ('Spider-Man 3', 'Sam Raimi', '2007-05-01', 258000000, 890871626),
#  ('The Lone Ranger', 'Gore Verbinski', '2013-07-03', 255000000, 89289910),
#  ('The Dark Knight Rises',
#   'Christopher Nolan',
#   '2012-07-16',
#   250000000,
#   1084939099),
#  ('Harry Potter and the Half-Blood Prince',
#   'David Yates',
#   '2009-07-07',
#   250000000,
#   933959197)]

# %%
df4=pd.DataFrame(highest_budget_movie, columns = ['original_title', 'director_name', 'release_date', 'budget', 'revenue'])

# %%
df4
# Out:
#                                 original_title      director_name  \
# 0  Pirates of the Caribbean: On Stranger Tides       Rob Marshall
# 1     Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                      Avengers: Age of Ultron        Joss Whedon
# 3                             Superman Returns       Bryan Singer
# 4                                  John Carter     Andrew Stanton
# 5                                      Tangled       Byron Howard
# 6                                 Spider-Man 3          Sam Raimi
# 7                              The Lone Ranger     Gore Verbinski
# 8                        The Dark Knight Rises  Christopher Nolan
# 9       Harry Potter and the Half-Blood Prince        David Yates
#
#   release_date     budget     revenue
# 0   2011-05-14  380000000  1045713802
# 1   2007-05-19  300000000   961000000
# 2   2015-04-22  280000000  1405403694
# 3   2006-06-28  270000000   391081192
# 4   2012-03-07  260000000   284139100
# ...

# %% [markdown]
# # Popularity Analysis

# %% [markdown]
# # Question- List out Top 10 popularity on movies

# %%
cur.execute('SELECT original_title, name, release_date, popularity, revenue FROM movies JOIN directors ON movies.director_id=directors.id ORDER BY popularity DESC limit 10')

# %%
highest_popularity_movie=cur.fetchall()

# %%
highest_popularity_movie
# Out:
# [('Minions', 'Kyle Balda', '2015-06-17', 875, 1156730962),
#  ('Interstellar', 'Christopher Nolan', '2014-11-05', 724, 675120017),
#  ('Deadpool', 'Tim Miller', '2016-02-09', 514, 783112979),
#  ('Guardians of the Galaxy', 'James Gunn', '2014-07-30', 481, 773328629),
#  ('Mad Max: Fury Road', 'George Miller', '2015-05-13', 434, 378858340),
#  ('Jurassic World', 'Colin Trevorrow', '2015-06-09', 418, 1513528810),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Gore Verbinski',
#   '2003-07-09',
#   271,
#   655011224),
#  ('Dawn of the Planet of the Apes',
#   'Matt Reeves',
#   '2014-06-26',
#   243,
#   710644566),
#  ('The Hunger Games: Mockingjay - Part 1',
#   'Francis Lawrence',
#   '2014-11-18',
#   206,
#   752100229),
#  ('Big Hero 6', 'Chris Williams', '2014-10-24', 203, 652105443)]

# %%
df5=pd.DataFrame(highest_popularity_movie, columns=['original_title', 'director_name', 'release_date', 'popularity', 'revenue'])

# %%
df5
# Out:
#                                       original_title      director_name  \
# 0                                            Minions         Kyle Balda
# 1                                       Interstellar  Christopher Nolan
# 2                                           Deadpool         Tim Miller
# 3                            Guardians of the Galaxy         James Gunn
# 4                                 Mad Max: Fury Road      George Miller
# 5                                     Jurassic World    Colin Trevorrow
# 6  Pirates of the Caribbean: The Curse of the Bla...     Gore Verbinski
# 7                     Dawn of the Planet of the Apes        Matt Reeves
# 8              The Hunger Games: Mockingjay - Part 1   Francis Lawrence
# 9                                         Big Hero 6     Chris Williams
#
#   release_date  popularity     revenue
# 0   2015-06-17         875  1156730962
# 1   2014-11-05         724   675120017
# 2   2016-02-09         514   783112979
# ...

# %% [markdown]
# # Revenu Analysis

# %% [markdown]
# # Question - What are the top 10 Revenue movies

# %%
cur.execute('SELECT original_title, name, release_date, revenue FROM movies JOIN directors ON movies.director_id=directors.id ORDER BY revenue DESC limit 10')

# %%
highest_revenue_movie=cur.fetchall()

# %%
highest_revenue_movie
# Out:
# [('Avatar', 'James Cameron', '2009-12-10', 2787965087),
#  ('Titanic', 'James Cameron', '1997-11-18', 1845034188),
#  ('The Avengers', 'Joss Whedon', '2012-04-25', 1519557910),
#  ('Jurassic World', 'Colin Trevorrow', '2015-06-09', 1513528810),
#  ('Furious 7', 'James Wan', '2015-04-01', 1506249360),
#  ('Avengers: Age of Ultron', 'Joss Whedon', '2015-04-22', 1405403694),
#  ('Frozen', 'Chris Buck', '2013-11-27', 1274219009),
#  ('Iron Man 3', 'Shane Black', '2013-04-18', 1215439994),
#  ('Minions', 'Kyle Balda', '2015-06-17', 1156730962),
#  ('Captain America: Civil War', 'Anthony Russo', '2016-04-27', 1153304495)]

# %%
df6=pd.DataFrame(highest_revenue_movie, columns=['original_title', 'director_name', 'release_date', 'revenue'])

# %%
df6
# Out:
#                original_title    director_name release_date     revenue
# 0                      Avatar    James Cameron   2009-12-10  2787965087
# 1                     Titanic    James Cameron   1997-11-18  1845034188
# 2                The Avengers      Joss Whedon   2012-04-25  1519557910
# 3              Jurassic World  Colin Trevorrow   2015-06-09  1513528810
# 4                   Furious 7        James Wan   2015-04-01  1506249360
# 5     Avengers: Age of Ultron      Joss Whedon   2015-04-22  1405403694
# 6                      Frozen       Chris Buck   2013-11-27  1274219009
# 7                  Iron Man 3      Shane Black   2013-04-18  1215439994
# 8                     Minions       Kyle Balda   2015-06-17  1156730962
# 9  Captain America: Civil War    Anthony Russo   2016-04-27  1153304495
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# # Voting Analysis

# %% [markdown]
# # Question - Display most popular movies with vote_average

# %%
cur.execute('SELECT original_title, name, release_date,vote_count, vote_average FROM movies JOIN directors ON movies.director_id=directors.id ORDER BY vote_average DESC limit 10')

# %%
highest_vote_average=cur.fetchall()

# %%
highest_vote_average
# Out:
# [('Stiff Upper Lips', 'Gary Sinyor', '1998-06-12', 1, 10.0),
#  ('Dancer, Texas Pop. 81', 'Tim McCanlies', '1998-05-01', 1, 10.0),
#  ('Sardaarji', 'Rohit Jugraj', '2015-06-26', 2, 9.5),
#  ("One Man's Hero", 'Lance Hool', '1999-08-02', 2, 9.3),
#  ('The Shawshank Redemption', 'Frank Darabont', '1994-09-23', 8205, 8.5),
#  ('There Goes My Baby', 'Floyd Mutrux', '1994-09-02', 2, 8.5),
#  ('The Prisoner of Zenda', 'John Cromwell', '1937-09-03', 11, 8.4),
#  ('The Godfather', 'Francis Ford Coppola', '1972-03-14', 5893, 8.4),
#  ('Fight Club', 'David Fincher', '1999-10-15', 9413, 8.3),
#  ("Schindler's List", 'Steven Spielberg', '1993-11-29', 4329, 8.3)]

# %%
df7=pd.DataFrame(highest_vote_average, columns=['original_title', 'director_name', 'release_date', 'vote_count','vote_average'])

# %%
df7
# Out:
#              original_title         director_name release_date  vote_count  \
# 0          Stiff Upper Lips           Gary Sinyor   1998-06-12           1
# 1     Dancer, Texas Pop. 81         Tim McCanlies   1998-05-01           1
# 2                 Sardaarji          Rohit Jugraj   2015-06-26           2
# 3            One Man's Hero            Lance Hool   1999-08-02           2
# 4  The Shawshank Redemption        Frank Darabont   1994-09-23        8205
# 5        There Goes My Baby          Floyd Mutrux   1994-09-02           2
# 6     The Prisoner of Zenda         John Cromwell   1937-09-03          11
# 7             The Godfather  Francis Ford Coppola   1972-03-14        5893
# 8                Fight Club         David Fincher   1999-10-15        9413
# 9          Schindler's List      Steven Spielberg   1993-11-29        4329
#
#    vote_average
# 0          10.0
# 1          10.0
# 2           9.5
# 3           9.3
# 4           8.5
# 5           8.5
# 6           8.4
# ...

# %% [markdown]
# # Question - List out most popular movie with Voting average by James Cameron

# %%
cur.execute('SELECT original_title, release_date, budget, revenue, popularity, vote_average FROM directors JOIN movies ON directors.id = movies.director_id WHERE name = "James Cameron" ORDER BY revenue DESC')
moviesByJamesCameron = cur.fetchall()
moviesByJamesCameron = pd.DataFrame(moviesByJamesCameron, columns = ['original_title', 'release_date', 'budget', 'revenue', 'popularity', 'vote_average'])
moviesByJamesCameron
# Out:
#                original_title release_date     budget     revenue  popularity  \
# 0                      Avatar   2009-12-10  237000000  2787965087         150
# 1                     Titanic   1997-11-18  200000000  1845034188         100
# 2  Terminator 2: Judgment Day   1991-07-01  100000000   520000000         101
# 3                   True Lies   1994-07-14  115000000   378882411          38
# 4                      Aliens   1986-07-18   18500000   183316455          67
# 5                   The Abyss   1989-08-09   70000000    90000098          24
# 6              The Terminator   1984-10-26    6400000    78371200          74
#
#    vote_average
# 0           7.2
# 1           7.5
# 2           7.7
# 3           6.8
# 4           7.7
# 5           7.1
# 6           7.3

# %% [markdown]
# # Directors

# %% [markdown]
# # Question- List out the director names with number of movies and revenue

# %%
cur.execute('SELECT name, COUNT(original_title), SUM(revenue) FROM directors JOIN movies ON movies.director_id=directors.id GROUP BY directors.name ORDER BY SUM(movies.revenue) DESC ')

# %%
mostProfitableDirector = cur.fetchall()

# %%
mostProfitableDirector = pd.DataFrame(mostProfitableDirector, columns = ['director_name', 'movies', 'revenue'])

# %%
mostProfitableDirector.head(10)
# Out:
#        director_name  movies     revenue
# 0   Steven Spielberg      27  9147393164
# 1      Peter Jackson       9  6498642820
# 2      James Cameron       7  5883569439
# 3        Michael Bay      12  5832524638
# 4  Christopher Nolan       8  4227483234
# 5     Chris Columbus      11  3725631503
# 6    Robert Zemeckis      13  3590622002
# 7       George Lucas       5  3339113893
# 8         Tim Burton      14  3337418241
# 9       Ridley Scott      16  3189557997

# %% [markdown]
# # Question - Display all the number of movies for particular director and revenue

# %%
cur.execute('SELECT name, COUNT(original_title), SUM(revenue) FROM directors JOIN movies ON movies.director_id=directors.id GROUP BY directors.name ORDER BY COUNT(movies.original_title) DESC ')

# %%
mostProductiveDirector = cur.fetchall()

# %%
mostProductiveDirector = pd.DataFrame(mostProductiveDirector, columns = ['director_name', 'movies', 'revenue'])

# %%
mostProductiveDirector.head(10)
# Out:
#        director_name  movies     revenue
# 0   Steven Spielberg      27  9147393164
# 1        Woody Allen      21   669101038
# 2    Martin Scorsese      20  1956635998
# 3     Clint Eastwood      20  2512058888
# 4          Spike Lee      16   340618771
# 5   Robert Rodriguez      16  1109899581
# 6       Ridley Scott      16  3189557997
# 7  Steven Soderbergh      15  2114864443
# 8       Renny Harlin      15  1031500590
# 9         Tim Burton      14  3337418241

# %% [markdown]
# # Question- By doing Director analysis We know Steven Spielberg is the highest revenue, so list the Steven Spielberg movies info

# %%
cur.execute('SELECT original_title, release_date, budget, revenue, popularity, vote_average FROM directors JOIN movies ON directors.id = movies.director_id WHERE name = "Steven Spielberg" ORDER BY release_date DESC')

# %%
moviesByStevenSpielberg = cur.fetchall()

# %%
moviesByStevenSpielberg = pd.DataFrame(moviesByStevenSpielberg, columns = ['original_title', 'release_date', 'budget', 'revenue', 'popularity', 'vote_average'])

# %%
moviesByStevenSpielberg
# Out:
#                                        original_title release_date     budget  \
# 0                                             The BFG   2016-06-01  140000000
# 1                                     Bridge of Spies   2015-10-15   40000000
# 2                                             Lincoln   2012-11-09   65000000
# 3                                           War Horse   2011-12-25   66000000
# 4                            The Adventures of Tintin   2011-10-25  130000000
# 5   Indiana Jones and the Kingdom of the Crystal S...   2008-05-21  185000000
# 6                                              Munich   2005-12-22   70000000
# 7                                   War of the Worlds   2005-06-28  132000000
# 8                                        The Terminal   2004-06-17   60000000
# 9                                 Catch Me If You Can   2002-12-25   52000000
# 10                                    Minority Report   2002-06-20  102000000
# ...
